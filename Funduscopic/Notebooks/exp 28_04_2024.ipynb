# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import shutil
import os
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import lite, keras
from tensorflow.keras import layers, backend
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, 
    Add, GlobalAveragePooling2D, Dense, Dropout, Flatten
)
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy, categorical_accuracy
from tensorflow.keras.preprocessing.image import (
    ImageDataGenerator, array_to_img, img_to_array, load_img
)
from tensorflow.keras.callbacks import CSVLogger

# %%
os.listdir('../Data/')
# Out:
# ['cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']

# %%
base_dir = "../Data/"
image_paths = []
classes = []
for class_folder in os.listdir(base_dir):
    class_path = os.path.join(base_dir, class_folder)
    
    if os.path.isdir(class_path):
        for image_file in os.listdir(class_path):
            image_paths.append(os.path.join(class_path, image_file))
            classes.append(class_folder)

df = pd.DataFrame({'image': image_paths, 'class': classes})
df.head()
# Out:
#                              image     class
# 0      ../Data/cataract\0_left.jpg  cataract
# 1    ../Data/cataract\103_left.jpg  cataract
# 2  ../Data/cataract\1062_right.jpg  cataract
# 3   ../Data/cataract\1083_left.jpg  cataract
# 4  ../Data/cataract\1084_right.jpg  cataract

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(y='class', data=df, hue='class', palette="Set3")
plt.title('Distribution of Types', fontsize=16)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Type', fontsize=14)
plt.show()

# %%
train, remain = train_test_split(df, train_size=0.8, stratify=df['class'], random_state=0)

# %%
test, valid = train_test_split(remain, train_size=0.5, stratify=remain['class'], random_state=0)

# %%
height = 512
width = 512
channels = 3
batch_size = 8
img_shape=(height, width, channels)
img_size=(height, width)
length=len(test)

test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

def scalar(img):
    img=img/255
    return img 

trgen=ImageDataGenerator(preprocessing_function=scalar, 
                         horizontal_flip=True, 
                         vertical_flip = True,
                         )
tvgen=ImageDataGenerator(preprocessing_function=scalar)


test_gen=tvgen.flow_from_dataframe( 
    test, 
    x_col='image', 
    y_col='class', 
    target_size=img_size, 
    class_mode='categorical',
    color_mode='rgb', 
    shuffle=False, 
    batch_size=test_batch_size)

train_gen = trgen.flow_from_dataframe(
        train,
        x_col='image',
        y_col='class',
        target_size=img_size,
        class_mode='categorical',
        color_mode='rgb',
        shuffle=True,
        batch_size=batch_size
    )

valid_gen = tvgen.flow_from_dataframe(
        valid,
        x_col='image',
        y_col='class',
        target_size=img_size,
        class_mode='categorical',
        color_mode='rgb',
        shuffle=True,
        batch_size=batch_size
    )
# Out:
# test batch size:  2   test steps:  211
# Found 422 validated image filenames belonging to 4 classes.
# Found 3373 validated image filenames belonging to 4 classes.
# Found 422 validated image filenames belonging to 4 classes.

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())    
    images,labels=next(gen) 
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<25:   
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='green', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-9)
early_stop = EarlyStopping(monitor='val_loss', patience=13, restore_best_weights=True)
callbacks = [reduce_lr, early_stop]

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key            
    classes=list(new_dict.values())     
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir,dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  
        if pred_index != true_index: 
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):                
                split1=os.path.split(error_list[i])                
                split2=os.path.split(split1[0])                
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))              
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) 
                plot_class.append(value)   
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)        
    y_pred=np.array(y_pred)
    if len(classes)<= 30:
        # Create a confusion matrix
        cm = confusion_matrix(y_true, y_pred)
        length = len(classes)
        if length < 8:
            fig_width = 8
            fig_height = 8
        else:
            fig_width = int(length * 0.5)
            fig_height = int(length * 0.5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=classes, yticklabels=classes)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %%
from tensorflow.keras.layers import Input, Conv2D, GlobalAveragePooling2D,GlobalMaxPooling2D, Dense, Dropout, Activation, Reshape, Multiply, MaxPooling2D, Add, Concatenate, DepthwiseConv2D, BatchNormalization
from tensorflow.keras.models import Model
import tensorflow as tf
from tensorflow.keras import regularizers

def cbam_block(input_feature, ratio=8, l2_reg=0.01):
    # Channel attention
    channel_avg = GlobalAveragePooling2D()(input_feature)
    channel_max = GlobalMaxPooling2D()(input_feature)
    channel_concat = Concatenate()([channel_avg, channel_max])
    channel_dense_1 = Dense(units=tf.keras.backend.int_shape(input_feature)[-1] // ratio, activation='relu', kernel_regularizer=regularizers.l2(l2_reg))(channel_concat)
    channel_dense_2 = Dense(units=tf.keras.backend.int_shape(input_feature)[-1], activation='sigmoid', kernel_regularizer=regularizers.l2(l2_reg))(channel_dense_1)
    channel_attention = Reshape((1, 1, -1))(channel_dense_2)
    channel_multiply = Multiply()([input_feature, channel_attention])

    spatial_avg = tf.keras.layers.Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(input_feature)
    spatial_max = tf.keras.layers.Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(input_feature)
    spatial_concat = Concatenate()([spatial_avg, spatial_max])
    spatial_conv = Conv2D(filters=1, kernel_size=(3, 3), padding='same', activation='sigmoid', kernel_regularizer=regularizers.l2(l2_reg))(spatial_concat)
    spatial_attention = Multiply()([input_feature, spatial_conv])

    cbam_feature = Add()([channel_multiply, spatial_attention])
    return cbam_feature

def create_model_with_cbam_and_skip(img_shape=(512, 512, 3), l2_reg=0.1):
    input_tensor = Input(shape=img_shape)

    base_model = tf.keras.applications.MobileNet(
        include_top=False,
        weights='imagenet', 
        input_tensor=input_tensor,  
        alpha=0.25
    )
    
    x = input_tensor
    for layer in base_model.layers[1:]: 
        x = layer(x)
        if isinstance(layer, DepthwiseConv2D):
            x = cbam_block(x, l2_reg=l2_reg)

    base = BatchNormalization()(x)
    base = MaxPooling2D(pool_size=(2,2))(base)
   

    x = cbam_block(base, l2_reg=l2_reg) 
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu', kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = Dropout(rate=0.3, seed=0)(x)
    output = Dense(4, activation='softmax')(x)
    model = Model(inputs=input_tensor, outputs=output)

    return model

model = create_model_with_cbam_and_skip(l2_reg=0.16)
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv1 (Conv2D)                 (None, 256, 256, 8)  216         ['input_1[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 256, 256, 8)  32          ['conv1[1][0]']
#
#  conv1_relu (ReLU)              (None, 256, 256, 8)  0           ['conv1_bn[1][0]']
#
#  conv_dw_1 (DepthwiseConv2D)    (None, 256, 256, 8)  72          ['conv1_relu[1][0]']
#
#  global_average_pooling2d (Glob  (None, 8)           0           ['conv_dw_1[1][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 8)           0           ['conv_dw_1[1][0]']
#  xPooling2D)
#
#  concatenate (Concatenate)      (None, 16)           0           ['global_average_pooling2d[0][0]'
#                                                                  , 'global_max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 1)            17          ['concatenate[0][0]']
#
#  lambda (Lambda)                (None, 256, 256, 1)  0           ['conv_dw_1[1][0]']
#
#  lambda_1 (Lambda)              (None, 256, 256, 1)  0           ['conv_dw_1[1][0]']
#
#  dense_1 (Dense)                (None, 8)            16          ['dense[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 256, 256, 2)  0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 8)      0           ['dense_1[0][0]']
#
#  conv2d (Conv2D)                (None, 256, 256, 1)  19          ['concatenate_1[0][0]']
#
#  multiply (Multiply)            (None, 256, 256, 8)  0           ['conv_dw_1[1][0]',
#                                                                   'reshape[0][0]']
#
#  multiply_1 (Multiply)          (None, 256, 256, 8)  0           ['conv_dw_1[1][0]',
#                                                                   'conv2d[0][0]']
#
#  add (Add)                      (None, 256, 256, 8)  0           ['multiply[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  conv_dw_1_bn (BatchNormalizati  (None, 256, 256, 8)  32         ['add[0][0]']
#  on)
#
#  conv_dw_1_relu (ReLU)          (None, 256, 256, 8)  0           ['conv_dw_1_bn[1][0]']
#
#  conv_pw_1 (Conv2D)             (None, 256, 256, 16  128         ['conv_dw_1_relu[1][0]']
#                                 )
#
#  conv_pw_1_bn (BatchNormalizati  (None, 256, 256, 16  64         ['conv_pw_1[1][0]']
#  on)                            )
#
#  conv_pw_1_relu (ReLU)          (None, 256, 256, 16  0           ['conv_pw_1_bn[1][0]']
#                                 )
#
#  conv_pad_2 (ZeroPadding2D)     (None, 257, 257, 16  0           ['conv_pw_1_relu[1][0]']
#                                 )
#
#  conv_dw_2 (DepthwiseConv2D)    (None, 128, 128, 16  144         ['conv_pad_2[1][0]']
#                                 )
#
#  global_average_pooling2d_1 (Gl  (None, 16)          0           ['conv_dw_2[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_1 (Global  (None, 16)          0           ['conv_dw_2[1][0]']
#  MaxPooling2D)
#
#  concatenate_2 (Concatenate)    (None, 32)           0           ['global_average_pooling2d_1[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_1[0][0]']
#
#  dense_2 (Dense)                (None, 2)            66          ['concatenate_2[0][0]']
#
#  lambda_2 (Lambda)              (None, 128, 128, 1)  0           ['conv_dw_2[1][0]']
#
#  lambda_3 (Lambda)              (None, 128, 128, 1)  0           ['conv_dw_2[1][0]']
#
#  dense_3 (Dense)                (None, 16)           48          ['dense_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 2)  0           ['lambda_2[0][0]',
#                                                                   'lambda_3[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 16)     0           ['dense_3[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 1)  19          ['concatenate_3[0][0]']
#
#  multiply_2 (Multiply)          (None, 128, 128, 16  0           ['conv_dw_2[1][0]',
#                                 )                                 'reshape_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 128, 128, 16  0           ['conv_dw_2[1][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  add_1 (Add)                    (None, 128, 128, 16  0           ['multiply_2[0][0]',
#                                 )                                 'multiply_3[0][0]']
#
#  conv_dw_2_bn (BatchNormalizati  (None, 128, 128, 16  64         ['add_1[0][0]']
#  on)                            )
#
#  conv_dw_2_relu (ReLU)          (None, 128, 128, 16  0           ['conv_dw_2_bn[1][0]']
#                                 )
#
#  conv_pw_2 (Conv2D)             (None, 128, 128, 32  512         ['conv_dw_2_relu[1][0]']
#                                 )
#
#  conv_pw_2_bn (BatchNormalizati  (None, 128, 128, 32  128        ['conv_pw_2[1][0]']
#  on)                            )
#
#  conv_pw_2_relu (ReLU)          (None, 128, 128, 32  0           ['conv_pw_2_bn[1][0]']
#                                 )
#
#  conv_dw_3 (DepthwiseConv2D)    (None, 128, 128, 32  288         ['conv_pw_2_relu[1][0]']
#                                 )
#
#  global_average_pooling2d_2 (Gl  (None, 32)          0           ['conv_dw_3[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_2 (Global  (None, 32)          0           ['conv_dw_3[1][0]']
#  MaxPooling2D)
#
#  concatenate_4 (Concatenate)    (None, 64)           0           ['global_average_pooling2d_2[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_2[0][0]']
#
#  dense_4 (Dense)                (None, 4)            260         ['concatenate_4[0][0]']
#
#  lambda_4 (Lambda)              (None, 128, 128, 1)  0           ['conv_dw_3[1][0]']
#
#  lambda_5 (Lambda)              (None, 128, 128, 1)  0           ['conv_dw_3[1][0]']
#
#  dense_5 (Dense)                (None, 32)           160         ['dense_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 2)  0           ['lambda_4[0][0]',
#                                                                   'lambda_5[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 1, 32)     0           ['dense_5[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 1)  19          ['concatenate_5[0][0]']
#
#  multiply_4 (Multiply)          (None, 128, 128, 32  0           ['conv_dw_3[1][0]',
#                                 )                                 'reshape_2[0][0]']
#
#  multiply_5 (Multiply)          (None, 128, 128, 32  0           ['conv_dw_3[1][0]',
#                                 )                                 'conv2d_2[0][0]']
#
#  add_2 (Add)                    (None, 128, 128, 32  0           ['multiply_4[0][0]',
#                                 )                                 'multiply_5[0][0]']
#
#  conv_dw_3_bn (BatchNormalizati  (None, 128, 128, 32  128        ['add_2[0][0]']
#  on)                            )
#
#  conv_dw_3_relu (ReLU)          (None, 128, 128, 32  0           ['conv_dw_3_bn[1][0]']
#                                 )
#
#  conv_pw_3 (Conv2D)             (None, 128, 128, 32  1024        ['conv_dw_3_relu[1][0]']
#                                 )
#
#  conv_pw_3_bn (BatchNormalizati  (None, 128, 128, 32  128        ['conv_pw_3[1][0]']
#  on)                            )
#
#  conv_pw_3_relu (ReLU)          (None, 128, 128, 32  0           ['conv_pw_3_bn[1][0]']
#                                 )
#
#  conv_pad_4 (ZeroPadding2D)     (None, 129, 129, 32  0           ['conv_pw_3_relu[1][0]']
#                                 )
#
#  conv_dw_4 (DepthwiseConv2D)    (None, 64, 64, 32)   288         ['conv_pad_4[1][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 32)          0           ['conv_dw_4[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_3 (Global  (None, 32)          0           ['conv_dw_4[1][0]']
#  MaxPooling2D)
#
#  concatenate_6 (Concatenate)    (None, 64)           0           ['global_average_pooling2d_3[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_3[0][0]']
#
#  dense_6 (Dense)                (None, 4)            260         ['concatenate_6[0][0]']
#
#  lambda_6 (Lambda)              (None, 64, 64, 1)    0           ['conv_dw_4[1][0]']
#
#  lambda_7 (Lambda)              (None, 64, 64, 1)    0           ['conv_dw_4[1][0]']
#
#  dense_7 (Dense)                (None, 32)           160         ['dense_6[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 2)    0           ['lambda_6[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  reshape_3 (Reshape)            (None, 1, 1, 32)     0           ['dense_7[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 1)    19          ['concatenate_7[0][0]']
#
#  multiply_6 (Multiply)          (None, 64, 64, 32)   0           ['conv_dw_4[1][0]',
#                                                                   'reshape_3[0][0]']
#
#  multiply_7 (Multiply)          (None, 64, 64, 32)   0           ['conv_dw_4[1][0]',
#                                                                   'conv2d_3[0][0]']
#
#  add_3 (Add)                    (None, 64, 64, 32)   0           ['multiply_6[0][0]',
#                                                                   'multiply_7[0][0]']
#
#  conv_dw_4_bn (BatchNormalizati  (None, 64, 64, 32)  128         ['add_3[0][0]']
#  on)
#
#  conv_dw_4_relu (ReLU)          (None, 64, 64, 32)   0           ['conv_dw_4_bn[1][0]']
#
#  conv_pw_4 (Conv2D)             (None, 64, 64, 64)   2048        ['conv_dw_4_relu[1][0]']
#
#  conv_pw_4_bn (BatchNormalizati  (None, 64, 64, 64)  256         ['conv_pw_4[1][0]']
#  on)
#
#  conv_pw_4_relu (ReLU)          (None, 64, 64, 64)   0           ['conv_pw_4_bn[1][0]']
#
#  conv_dw_5 (DepthwiseConv2D)    (None, 64, 64, 64)   576         ['conv_pw_4_relu[1][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 64)          0           ['conv_dw_5[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_4 (Global  (None, 64)          0           ['conv_dw_5[1][0]']
#  MaxPooling2D)
#
#  concatenate_8 (Concatenate)    (None, 128)          0           ['global_average_pooling2d_4[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_4[0][0]']
#
#  dense_8 (Dense)                (None, 8)            1032        ['concatenate_8[0][0]']
#
#  lambda_8 (Lambda)              (None, 64, 64, 1)    0           ['conv_dw_5[1][0]']
#
#  lambda_9 (Lambda)              (None, 64, 64, 1)    0           ['conv_dw_5[1][0]']
#
#  dense_9 (Dense)                (None, 64)           576         ['dense_8[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 64, 64, 2)    0           ['lambda_8[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  reshape_4 (Reshape)            (None, 1, 1, 64)     0           ['dense_9[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 1)    19          ['concatenate_9[0][0]']
#
#  multiply_8 (Multiply)          (None, 64, 64, 64)   0           ['conv_dw_5[1][0]',
#                                                                   'reshape_4[0][0]']
#
#  multiply_9 (Multiply)          (None, 64, 64, 64)   0           ['conv_dw_5[1][0]',
#                                                                   'conv2d_4[0][0]']
#
#  add_4 (Add)                    (None, 64, 64, 64)   0           ['multiply_8[0][0]',
#                                                                   'multiply_9[0][0]']
#
#  conv_dw_5_bn (BatchNormalizati  (None, 64, 64, 64)  256         ['add_4[0][0]']
#  on)
#
#  conv_dw_5_relu (ReLU)          (None, 64, 64, 64)   0           ['conv_dw_5_bn[1][0]']
#
#  conv_pw_5 (Conv2D)             (None, 64, 64, 64)   4096        ['conv_dw_5_relu[1][0]']
#
#  conv_pw_5_bn (BatchNormalizati  (None, 64, 64, 64)  256         ['conv_pw_5[1][0]']
#  on)
#
#  conv_pw_5_relu (ReLU)          (None, 64, 64, 64)   0           ['conv_pw_5_bn[1][0]']
#
#  conv_pad_6 (ZeroPadding2D)     (None, 65, 65, 64)   0           ['conv_pw_5_relu[1][0]']
#
#  conv_dw_6 (DepthwiseConv2D)    (None, 32, 32, 64)   576         ['conv_pad_6[1][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 64)          0           ['conv_dw_6[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_5 (Global  (None, 64)          0           ['conv_dw_6[1][0]']
#  MaxPooling2D)
#
#  concatenate_10 (Concatenate)   (None, 128)          0           ['global_average_pooling2d_5[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_5[0][0]']
#
#  dense_10 (Dense)               (None, 8)            1032        ['concatenate_10[0][0]']
#
#  lambda_10 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_6[1][0]']
#
#  lambda_11 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_6[1][0]']
#
#  dense_11 (Dense)               (None, 64)           576         ['dense_10[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 32, 32, 2)    0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  reshape_5 (Reshape)            (None, 1, 1, 64)     0           ['dense_11[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 1)    19          ['concatenate_11[0][0]']
#
#  multiply_10 (Multiply)         (None, 32, 32, 64)   0           ['conv_dw_6[1][0]',
#                                                                   'reshape_5[0][0]']
#
#  multiply_11 (Multiply)         (None, 32, 32, 64)   0           ['conv_dw_6[1][0]',
#                                                                   'conv2d_5[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 64)   0           ['multiply_10[0][0]',
#                                                                   'multiply_11[0][0]']
#
#  conv_dw_6_bn (BatchNormalizati  (None, 32, 32, 64)  256         ['add_5[0][0]']
#  on)
#
#  conv_dw_6_relu (ReLU)          (None, 32, 32, 64)   0           ['conv_dw_6_bn[1][0]']
#
#  conv_pw_6 (Conv2D)             (None, 32, 32, 128)  8192        ['conv_dw_6_relu[1][0]']
#
#  conv_pw_6_bn (BatchNormalizati  (None, 32, 32, 128)  512        ['conv_pw_6[1][0]']
#  on)
#
#  conv_pw_6_relu (ReLU)          (None, 32, 32, 128)  0           ['conv_pw_6_bn[1][0]']
#
#  conv_dw_7 (DepthwiseConv2D)    (None, 32, 32, 128)  1152        ['conv_pw_6_relu[1][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 128)         0           ['conv_dw_7[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_6 (Global  (None, 128)         0           ['conv_dw_7[1][0]']
#  MaxPooling2D)
#
#  concatenate_12 (Concatenate)   (None, 256)          0           ['global_average_pooling2d_6[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_6[0][0]']
#
#  dense_12 (Dense)               (None, 16)           4112        ['concatenate_12[0][0]']
#
#  lambda_12 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_7[1][0]']
#
#  lambda_13 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_7[1][0]']
#
#  dense_13 (Dense)               (None, 128)          2176        ['dense_12[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 32, 32, 2)    0           ['lambda_12[0][0]',
#                                                                   'lambda_13[0][0]']
#
#  reshape_6 (Reshape)            (None, 1, 1, 128)    0           ['dense_13[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 1)    19          ['concatenate_13[0][0]']
#
#  multiply_12 (Multiply)         (None, 32, 32, 128)  0           ['conv_dw_7[1][0]',
#                                                                   'reshape_6[0][0]']
#
#  multiply_13 (Multiply)         (None, 32, 32, 128)  0           ['conv_dw_7[1][0]',
#                                                                   'conv2d_6[0][0]']
#
#  add_6 (Add)                    (None, 32, 32, 128)  0           ['multiply_12[0][0]',
#                                                                   'multiply_13[0][0]']
#
#  conv_dw_7_bn (BatchNormalizati  (None, 32, 32, 128)  512        ['add_6[0][0]']
#  on)
#
#  conv_dw_7_relu (ReLU)          (None, 32, 32, 128)  0           ['conv_dw_7_bn[1][0]']
#
#  conv_pw_7 (Conv2D)             (None, 32, 32, 128)  16384       ['conv_dw_7_relu[1][0]']
#
#  conv_pw_7_bn (BatchNormalizati  (None, 32, 32, 128)  512        ['conv_pw_7[1][0]']
#  on)
#
#  conv_pw_7_relu (ReLU)          (None, 32, 32, 128)  0           ['conv_pw_7_bn[1][0]']
#
#  conv_dw_8 (DepthwiseConv2D)    (None, 32, 32, 128)  1152        ['conv_pw_7_relu[1][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 128)         0           ['conv_dw_8[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_7 (Global  (None, 128)         0           ['conv_dw_8[1][0]']
#  MaxPooling2D)
#
#  concatenate_14 (Concatenate)   (None, 256)          0           ['global_average_pooling2d_7[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_7[0][0]']
#
#  dense_14 (Dense)               (None, 16)           4112        ['concatenate_14[0][0]']
#
#  lambda_14 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_8[1][0]']
#
#  lambda_15 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_8[1][0]']
#
#  dense_15 (Dense)               (None, 128)          2176        ['dense_14[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 32, 32, 2)    0           ['lambda_14[0][0]',
#                                                                   'lambda_15[0][0]']
#
#  reshape_7 (Reshape)            (None, 1, 1, 128)    0           ['dense_15[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 1)    19          ['concatenate_15[0][0]']
#
#  multiply_14 (Multiply)         (None, 32, 32, 128)  0           ['conv_dw_8[1][0]',
#                                                                   'reshape_7[0][0]']
#
#  multiply_15 (Multiply)         (None, 32, 32, 128)  0           ['conv_dw_8[1][0]',
#                                                                   'conv2d_7[0][0]']
#
#  add_7 (Add)                    (None, 32, 32, 128)  0           ['multiply_14[0][0]',
#                                                                   'multiply_15[0][0]']
#
#  conv_dw_8_bn (BatchNormalizati  (None, 32, 32, 128)  512        ['add_7[0][0]']
#  on)
#
#  conv_dw_8_relu (ReLU)          (None, 32, 32, 128)  0           ['conv_dw_8_bn[1][0]']
#
#  conv_pw_8 (Conv2D)             (None, 32, 32, 128)  16384       ['conv_dw_8_relu[1][0]']
#
#  conv_pw_8_bn (BatchNormalizati  (None, 32, 32, 128)  512        ['conv_pw_8[1][0]']
#  on)
#
#  conv_pw_8_relu (ReLU)          (None, 32, 32, 128)  0           ['conv_pw_8_bn[1][0]']
#
#  conv_dw_9 (DepthwiseConv2D)    (None, 32, 32, 128)  1152        ['conv_pw_8_relu[1][0]']
#
#  global_average_pooling2d_8 (Gl  (None, 128)         0           ['conv_dw_9[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_8 (Global  (None, 128)         0           ['conv_dw_9[1][0]']
#  MaxPooling2D)
#
#  concatenate_16 (Concatenate)   (None, 256)          0           ['global_average_pooling2d_8[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_8[0][0]']
#
#  dense_16 (Dense)               (None, 16)           4112        ['concatenate_16[0][0]']
#
#  lambda_16 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_9[1][0]']
#
#  lambda_17 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_9[1][0]']
#
#  dense_17 (Dense)               (None, 128)          2176        ['dense_16[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 32, 32, 2)    0           ['lambda_16[0][0]',
#                                                                   'lambda_17[0][0]']
#
#  reshape_8 (Reshape)            (None, 1, 1, 128)    0           ['dense_17[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1)    19          ['concatenate_17[0][0]']
#
#  multiply_16 (Multiply)         (None, 32, 32, 128)  0           ['conv_dw_9[1][0]',
#                                                                   'reshape_8[0][0]']
#
#  multiply_17 (Multiply)         (None, 32, 32, 128)  0           ['conv_dw_9[1][0]',
#                                                                   'conv2d_8[0][0]']
#
#  add_8 (Add)                    (None, 32, 32, 128)  0           ['multiply_16[0][0]',
#                                                                   'multiply_17[0][0]']
#
#  conv_dw_9_bn (BatchNormalizati  (None, 32, 32, 128)  512        ['add_8[0][0]']
#  on)
#
#  conv_dw_9_relu (ReLU)          (None, 32, 32, 128)  0           ['conv_dw_9_bn[1][0]']
#
#  conv_pw_9 (Conv2D)             (None, 32, 32, 128)  16384       ['conv_dw_9_relu[1][0]']
#
#  conv_pw_9_bn (BatchNormalizati  (None, 32, 32, 128)  512        ['conv_pw_9[1][0]']
#  on)
#
#  conv_pw_9_relu (ReLU)          (None, 32, 32, 128)  0           ['conv_pw_9_bn[1][0]']
#
#  conv_dw_10 (DepthwiseConv2D)   (None, 32, 32, 128)  1152        ['conv_pw_9_relu[1][0]']
#
#  global_average_pooling2d_9 (Gl  (None, 128)         0           ['conv_dw_10[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_9 (Global  (None, 128)         0           ['conv_dw_10[1][0]']
#  MaxPooling2D)
#
#  concatenate_18 (Concatenate)   (None, 256)          0           ['global_average_pooling2d_9[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_9[0][0]']
#
#  dense_18 (Dense)               (None, 16)           4112        ['concatenate_18[0][0]']
#
#  lambda_18 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_10[1][0]']
#
#  lambda_19 (Lambda)             (None, 32, 32, 1)    0           ['conv_dw_10[1][0]']
#
#  dense_19 (Dense)               (None, 128)          2176        ['dense_18[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 32, 32, 2)    0           ['lambda_18[0][0]',
# ...
#  ion)
#
#  conv_dw_11_relu (ReLU)         (None, 32, 32, 128)  0           ['conv_dw_11_bn[1][0]']
#
#  conv_pw_11 (Conv2D)            (None, 32, 32, 128)  16384       ['conv_dw_11_relu[1][0]']
#
#  conv_pw_11_bn (BatchNormalizat  (None, 32, 32, 128)  512        ['conv_pw_11[1][0]']
#  ion)
#
#  conv_pw_11_relu (ReLU)         (None, 32, 32, 128)  0           ['conv_pw_11_bn[1][0]']
#
#  conv_pad_12 (ZeroPadding2D)    (None, 33, 33, 128)  0           ['conv_pw_11_relu[1][0]']
#
#  conv_dw_12 (DepthwiseConv2D)   (None, 16, 16, 128)  1152        ['conv_pad_12[1][0]']
#
#  global_average_pooling2d_11 (G  (None, 128)         0           ['conv_dw_12[1][0]']
#  lobalAveragePooling2D)
#
#  global_max_pooling2d_11 (Globa  (None, 128)         0           ['conv_dw_12[1][0]']
#  lMaxPooling2D)
#
#  concatenate_22 (Concatenate)   (None, 256)          0           ['global_average_pooling2d_11[0][
#                                                                  0]',
#                                                                   'global_max_pooling2d_11[0][0]']
#
#  dense_22 (Dense)               (None, 16)           4112        ['concatenate_22[0][0]']
#
#  lambda_22 (Lambda)             (None, 16, 16, 1)    0           ['conv_dw_12[1][0]']
#
#  lambda_23 (Lambda)             (None, 16, 16, 1)    0           ['conv_dw_12[1][0]']
#
#  dense_23 (Dense)               (None, 128)          2176        ['dense_22[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 16, 16, 2)    0           ['lambda_22[0][0]',
#                                                                   'lambda_23[0][0]']
#
#  reshape_11 (Reshape)           (None, 1, 1, 128)    0           ['dense_23[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 1)    19          ['concatenate_23[0][0]']
#
#  multiply_22 (Multiply)         (None, 16, 16, 128)  0           ['conv_dw_12[1][0]',
#                                                                   'reshape_11[0][0]']
#
#  multiply_23 (Multiply)         (None, 16, 16, 128)  0           ['conv_dw_12[1][0]',
#                                                                   'conv2d_11[0][0]']
#
#  add_11 (Add)                   (None, 16, 16, 128)  0           ['multiply_22[0][0]',
#                                                                   'multiply_23[0][0]']
#
#  conv_dw_12_bn (BatchNormalizat  (None, 16, 16, 128)  512        ['add_11[0][0]']
#  ion)
#
#  conv_dw_12_relu (ReLU)         (None, 16, 16, 128)  0           ['conv_dw_12_bn[1][0]']
#
#  conv_pw_12 (Conv2D)            (None, 16, 16, 256)  32768       ['conv_dw_12_relu[1][0]']
#
#  conv_pw_12_bn (BatchNormalizat  (None, 16, 16, 256)  1024       ['conv_pw_12[1][0]']
#  ion)
#
#  conv_pw_12_relu (ReLU)         (None, 16, 16, 256)  0           ['conv_pw_12_bn[1][0]']
#
#  conv_dw_13 (DepthwiseConv2D)   (None, 16, 16, 256)  2304        ['conv_pw_12_relu[1][0]']
#
#  global_average_pooling2d_12 (G  (None, 256)         0           ['conv_dw_13[1][0]']
#  lobalAveragePooling2D)
#
#  global_max_pooling2d_12 (Globa  (None, 256)         0           ['conv_dw_13[1][0]']
#  lMaxPooling2D)
#
#  concatenate_24 (Concatenate)   (None, 512)          0           ['global_average_pooling2d_12[0][
#                                                                  0]',
#                                                                   'global_max_pooling2d_12[0][0]']
#
#  dense_24 (Dense)               (None, 32)           16416       ['concatenate_24[0][0]']
#
#  lambda_24 (Lambda)             (None, 16, 16, 1)    0           ['conv_dw_13[1][0]']
#
#  lambda_25 (Lambda)             (None, 16, 16, 1)    0           ['conv_dw_13[1][0]']
#
#  dense_25 (Dense)               (None, 256)          8448        ['dense_24[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 16, 16, 2)    0           ['lambda_24[0][0]',
#                                                                   'lambda_25[0][0]']
#
#  reshape_12 (Reshape)           (None, 1, 1, 256)    0           ['dense_25[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 1)    19          ['concatenate_25[0][0]']
#
#  multiply_24 (Multiply)         (None, 16, 16, 256)  0           ['conv_dw_13[1][0]',
#                                                                   'reshape_12[0][0]']
#
#  multiply_25 (Multiply)         (None, 16, 16, 256)  0           ['conv_dw_13[1][0]',
#                                                                   'conv2d_12[0][0]']
#
#  add_12 (Add)                   (None, 16, 16, 256)  0           ['multiply_24[0][0]',
#                                                                   'multiply_25[0][0]']
#
#  conv_dw_13_bn (BatchNormalizat  (None, 16, 16, 256)  1024       ['add_12[0][0]']
#  ion)
#
#  conv_dw_13_relu (ReLU)         (None, 16, 16, 256)  0           ['conv_dw_13_bn[1][0]']
#
#  conv_pw_13 (Conv2D)            (None, 16, 16, 256)  65536       ['conv_dw_13_relu[1][0]']
#
#  conv_pw_13_bn (BatchNormalizat  (None, 16, 16, 256)  1024       ['conv_pw_13[1][0]']
#  ion)
#
#  conv_pw_13_relu (ReLU)         (None, 16, 16, 256)  0           ['conv_pw_13_bn[1][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 256)  1024       ['conv_pw_13_relu[1][0]']
#  alization)
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 256)    0           ['batch_normalization[0][0]']
#
#  global_average_pooling2d_13 (G  (None, 256)         0           ['max_pooling2d[0][0]']
#  lobalAveragePooling2D)
#
#  global_max_pooling2d_13 (Globa  (None, 256)         0           ['max_pooling2d[0][0]']
#  lMaxPooling2D)
#
#  concatenate_26 (Concatenate)   (None, 512)          0           ['global_average_pooling2d_13[0][
#                                                                  0]',
#                                                                   'global_max_pooling2d_13[0][0]']
#
#  dense_26 (Dense)               (None, 32)           16416       ['concatenate_26[0][0]']
#
#  lambda_26 (Lambda)             (None, 8, 8, 1)      0           ['max_pooling2d[0][0]']
#
#  lambda_27 (Lambda)             (None, 8, 8, 1)      0           ['max_pooling2d[0][0]']
#
#  dense_27 (Dense)               (None, 256)          8448        ['dense_26[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 8, 8, 2)      0           ['lambda_26[0][0]',
#                                                                   'lambda_27[0][0]']
#
#  reshape_13 (Reshape)           (None, 1, 1, 256)    0           ['dense_27[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 1)      19          ['concatenate_27[0][0]']
#
#  multiply_26 (Multiply)         (None, 8, 8, 256)    0           ['max_pooling2d[0][0]',
#                                                                   'reshape_13[0][0]']
#
#  multiply_27 (Multiply)         (None, 8, 8, 256)    0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  add_13 (Add)                   (None, 8, 8, 256)    0           ['multiply_26[0][0]',
#                                                                   'multiply_27[0][0]']
#
#  global_average_pooling2d_14 (G  (None, 256)         0           ['add_13[0][0]']
#  lobalAveragePooling2D)
#
#  dense_28 (Dense)               (None, 256)          65792       ['global_average_pooling2d_14[0][
#                                                                  0]']
#
#  dropout (Dropout)              (None, 256)          0           ['dense_28[0][0]']
#
#  dense_29 (Dense)               (None, 4)            1028        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 378,313
# Trainable params: 372,329
# Non-trainable params: 5,984
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy',tf.keras.metrics.AUC()])

# %%
model.save('temp_model.h5')

# %%
epochs = 120
train_step = int(train_gen.samples/batch_size)
valid_step = int(valid_gen.samples/batch_size)

history = model.fit(
    x=train_gen,
    epochs=epochs,
    steps_per_epoch=train_step,  
    batch_size = batch_size,
    verbose=1,
    callbacks=callbacks,
    validation_data=valid_gen,
    validation_steps=valid_step,
    initial_epoch=0
)
# Out:
# Epoch 1/120
# 421/421 [==============================] - 50s 102ms/step - loss: 8.9658 - accuracy: 0.5780 - auc: 0.8316 - val_loss: 7.4497 - val_accuracy: 0.6707 - val_auc: 0.8913 - lr: 1.0000e-04
# Epoch 2/120
# 421/421 [==============================] - 40s 96ms/step - loss: 6.4430 - accuracy: 0.7135 - auc: 0.9135 - val_loss: 5.5794 - val_accuracy: 0.7596 - val_auc: 0.9321 - lr: 1.0000e-04
# Epoch 3/120
# 421/421 [==============================] - 42s 99ms/step - loss: 5.0091 - accuracy: 0.7569 - auc: 0.9336 - val_loss: 4.4305 - val_accuracy: 0.7861 - val_auc: 0.9527 - lr: 1.0000e-04
# Epoch 4/120
# 421/421 [==============================] - 43s 102ms/step - loss: 4.0855 - accuracy: 0.7860 - auc: 0.9471 - val_loss: 3.6494 - val_accuracy: 0.8197 - val_auc: 0.9661 - lr: 1.0000e-04
# Epoch 5/120
# 421/421 [==============================] - 43s 102ms/step - loss: 3.4495 - accuracy: 0.8062 - auc: 0.9574 - val_loss: 3.1480 - val_accuracy: 0.8173 - val_auc: 0.9675 - lr: 1.0000e-04
# Epoch 6/120
# 421/421 [==============================] - 43s 102ms/step - loss: 2.9856 - accuracy: 0.8270 - auc: 0.9641 - val_loss: 2.7932 - val_accuracy: 0.8317 - val_auc: 0.9666 - lr: 1.0000e-04
# 421/421 [==============================] - 66s 156ms/step - loss: 0.4316 - accuracy: 0.9605 - auc: 0.9975 - val_loss: 0.4921 - val_accuracy: 0.9279 - val_auc: 0.9949 - lr: 1.0000e-09
# Epoch 62/120
# 421/421 [==============================] - 65s 154ms/step - loss: 0.4399 - accuracy: 0.9557 - auc: 0.9969 - val_loss: 0.4915 - val_accuracy: 0.9303 - val_auc: 0.9950 - lr: 1.0000e-09
# Epoch 63/120
# 421/421 [==============================] - 65s 155ms/step - loss: 0.4301 - accuracy: 0.9605 - auc: 0.9977 - val_loss: 0.4929 - val_accuracy: 0.9327 - val_auc: 0.9948 - lr: 1.0000e-09
# Epoch 64/120
# 421/421 [==============================] - 66s 156ms/step - loss: 0.4337 - accuracy: 0.9599 - auc: 0.9976 - val_loss: 0.4924 - val_accuracy: 0.9303 - val_auc: 0.9949 - lr: 1.0000e-09
# Epoch 65/120
# 421/421 [==============================] - 66s 157ms/step - loss: 0.4381 - accuracy: 0.9566 - auc: 0.9975 - val_loss: 0.4900 - val_accuracy: 0.9303 - val_auc: 0.9950 - lr: 1.0000e-09

# %%
import seaborn as sns
import matplotlib.pyplot as plt
####################################
sns.set(style='whitegrid')
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))
sns.lineplot(x=range(1, len(history.history['accuracy']) + 1), y=history.history['accuracy'], ax=axes[0], label='train')   
sns.lineplot(x=range(1, len(history.history['val_accuracy']) + 1), y=history.history['val_accuracy'], ax=axes[0], label='test')
axes[0].set_title('Model Accuracy')
axes[0].set_ylabel('Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].legend(loc='upper left')

sns.lineplot(x=range(1, len(history.history['loss']) + 1), y=history.history['loss'], ax=axes[1], label='train')
sns.lineplot(x=range(1, len(history.history['val_loss']) + 1), y=history.history['val_loss'], ax=axes[1], label='test')
axes[1].set_title('Model Loss')
axes[1].set_ylabel('Loss')
axes[1].set_xlabel('Epoch')
axes[1].legend(loc='upper right')
plt.tight_layout()
plt.show()
####################################

# %%
pred = model.predict(test_gen)
print_code = 0
save_dir = "./"
subject='classes'
print_info( test_gen, pred, print_code, save_dir, subject)
# Out:
# 211/211 [==============================] - 4s 19ms/step
# Classification Report:
# ----------------------
#                        precision    recall  f1-score   support
#
#             cataract       0.93      0.96      0.94       104
# diabetic_retinopathy       1.00      0.98      0.99       110
#             glaucoma       0.91      0.83      0.87       100
#               normal       0.88      0.94      0.91       108
#
#             accuracy                           0.93       422
#            macro avg       0.93      0.93      0.93       422
#         weighted avg       0.93      0.93      0.93       422

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

pred_prob = model.predict(test_gen)

fpr = {}
tpr = {}
thresh ={}

n_class = 4

for i in range(n_class):
    fpr[i], tpr[i], thresh[i] = roc_curve(test_gen.classes, pred_prob[:,i], pos_label=i)


plt.plot(fpr[0], tpr[0], linestyle='--',color='green', label='glacoma')
plt.plot(fpr[1], tpr[1], linestyle='--',color='yellow', label='diabetic retinopathy')
plt.plot(fpr[2], tpr[2], linestyle='--',color='black', label='cataract')
plt.plot(fpr[3], tpr[3], linestyle='--',color='red', label='normal')


plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
# Out:
# 211/211 [==============================] - 4s 19ms/step
