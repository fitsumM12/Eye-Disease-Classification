# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import shutil
import os
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import lite, keras
from tensorflow.keras import layers, backend
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, 
    Add, GlobalAveragePooling2D, Dense, Dropout, Flatten
)
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy, categorical_accuracy
from tensorflow.keras.preprocessing.image import (
    ImageDataGenerator, array_to_img, img_to_array, load_img
)
from tensorflow.keras.callbacks import CSVLogger

# %%
os.listdir('../Data/')
# Out:
# ['cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']

# %%
base_dir = "../Data/"
image_paths = []
classes = []
for class_folder in os.listdir(base_dir):
    class_path = os.path.join(base_dir, class_folder)
    
    if os.path.isdir(class_path):
        for image_file in os.listdir(class_path):
            image_paths.append(os.path.join(class_path, image_file))
            classes.append(class_folder)

df = pd.DataFrame({'image': image_paths, 'class': classes})
df.head()
# Out:
#                              image     class
# 0      ../Data/cataract\0_left.jpg  cataract
# 1    ../Data/cataract\103_left.jpg  cataract
# 2  ../Data/cataract\1062_right.jpg  cataract
# 3   ../Data/cataract\1083_left.jpg  cataract
# 4  ../Data/cataract\1084_right.jpg  cataract

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(y='class', data=df, hue='class', palette="Set3")
plt.title('Distribution of Types', fontsize=16)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Type', fontsize=14)
plt.show()

# %%
remain, test = train_test_split(df, train_size=0.9, stratify=df['class'], random_state=0)

# %%
train, valid = train_test_split(remain, train_size=0.9, stratify=remain['class'], random_state=0)

# %%
height = 512
width = 512
channels = 3
batch_size = 64
img_shape=(height, width, channels)
img_size=(height, width)
length=len(test)

test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

def scalar(img):
    img=img/255
    return img 

trgen=ImageDataGenerator(preprocessing_function=scalar, 
                         horizontal_flip=True, 
                         vertical_flip = True,
                         )
tvgen=ImageDataGenerator(preprocessing_function=scalar)


test_gen=tvgen.flow_from_dataframe( 
    test, 
    x_col='image', 
    y_col='class', 
    target_size=img_size, 
    class_mode='categorical',
    color_mode='rgb', 
    shuffle=False, 
    batch_size=test_batch_size)

train_gen = trgen.flow_from_dataframe(
        train,
        x_col='image',
        y_col='class',
        target_size=img_size,
        class_mode='categorical',
        color_mode='rgb',
        shuffle=True,
        batch_size=batch_size
    )

valid_gen = tvgen.flow_from_dataframe(
        valid,
        x_col='image',
        y_col='class',
        target_size=img_size,
        class_mode='categorical',
        color_mode='rgb',
        shuffle=True,
        batch_size=batch_size
    )
# Out:
# test batch size:  2   test steps:  211
# Found 422 validated image filenames belonging to 4 classes.
# Found 3415 validated image filenames belonging to 4 classes.
# Found 380 validated image filenames belonging to 4 classes.

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())    
    images,labels=next(gen) 
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<25:   
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='green', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
def create_model(img_shape=(512,512, 3)):
    input_tensor = Input(shape=img_shape)
    base_model = tf.keras.applications.MobileNet(
        include_top=False,
        weights='imagenet', 
        input_tensor=input_tensor,  
        alpha=0.25
    )
    x = base_model.output
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(256, activation='relu')(x)
    x = Dropout(rate=0.3, seed=0)(x)
    output = Dense(4, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=output)

    return model

model = create_model()
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]     0
#
#  conv1 (Conv2D)              (None, 256, 256, 8)       216
#
#  conv1_bn (BatchNormalizatio  (None, 256, 256, 8)      32
#  n)
#
#  conv1_relu (ReLU)           (None, 256, 256, 8)       0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 256, 256, 8)      72
#
#  conv_dw_1_bn (BatchNormaliz  (None, 256, 256, 8)      32
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 256, 256, 8)       0
#
#  conv_pw_1 (Conv2D)          (None, 256, 256, 16)      128
#
#  conv_pw_1_bn (BatchNormaliz  (None, 256, 256, 16)     64
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 256, 256, 16)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 257, 257, 16)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 128, 128, 16)     144
#
#  conv_dw_2_bn (BatchNormaliz  (None, 128, 128, 16)     64
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 128, 128, 16)      0
#
#  conv_pw_2 (Conv2D)          (None, 128, 128, 32)      512
#
#  conv_pw_2_bn (BatchNormaliz  (None, 128, 128, 32)     128
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 128, 128, 32)      0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 128, 128, 32)     288
#
#  conv_dw_3_bn (BatchNormaliz  (None, 128, 128, 32)     128
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 128, 128, 32)      0
#
#  conv_pw_3 (Conv2D)          (None, 128, 128, 32)      1024
#
#  conv_pw_3_bn (BatchNormaliz  (None, 128, 128, 32)     128
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 128, 128, 32)      0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 129, 129, 32)      0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 64, 64, 32)       288
#
#  conv_dw_4_bn (BatchNormaliz  (None, 64, 64, 32)       128
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 64, 64, 32)        0
#
#  conv_pw_4 (Conv2D)          (None, 64, 64, 64)        2048
#
#  conv_pw_4_bn (BatchNormaliz  (None, 64, 64, 64)       256
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 64, 64, 64)        0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 64, 64, 64)       576
#
#  conv_dw_5_bn (BatchNormaliz  (None, 64, 64, 64)       256
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 64, 64, 64)        0
#
#  conv_pw_5 (Conv2D)          (None, 64, 64, 64)        4096
#
#  conv_pw_5_bn (BatchNormaliz  (None, 64, 64, 64)       256
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 64, 64, 64)        0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 65, 65, 64)        0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 32, 32, 64)       576
#
#  conv_dw_6_bn (BatchNormaliz  (None, 32, 32, 64)       256
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 32, 32, 64)        0
#
#  conv_pw_6 (Conv2D)          (None, 32, 32, 128)       8192
#
#  conv_pw_6_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 32, 32, 128)      1152
#
#  conv_dw_7_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_pw_7 (Conv2D)          (None, 32, 32, 128)       16384
#
#  conv_pw_7_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 32, 32, 128)      1152
#
#  conv_dw_8_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_pw_8 (Conv2D)          (None, 32, 32, 128)       16384
#
#  conv_pw_8_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 32, 32, 128)      1152
#
#  conv_dw_9_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_pw_9 (Conv2D)          (None, 32, 32, 128)       16384
#
#  conv_pw_9_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 32, 32, 128)      1152
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 32, 32, 128)      512
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 32, 32, 128)       0
#
#  conv_pw_10 (Conv2D)         (None, 32, 32, 128)       16384
#
#  conv_pw_10_bn (BatchNormali  (None, 32, 32, 128)      512
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 32, 32, 128)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 32, 32, 128)      1152
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 32, 32, 128)      512
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 32, 32, 128)       0
#
#  conv_pw_11 (Conv2D)         (None, 32, 32, 128)       16384
#
#  conv_pw_11_bn (BatchNormali  (None, 32, 32, 128)      512
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 32, 32, 128)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 33, 33, 128)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 16, 16, 128)      1152
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 16, 16, 128)      512
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 16, 16, 128)       0
#
#  conv_pw_12 (Conv2D)         (None, 16, 16, 256)       32768
#
#  conv_pw_12_bn (BatchNormali  (None, 16, 16, 256)      1024
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 16, 16, 256)       0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 16, 16, 256)      2304
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 16, 16, 256)      1024
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 16, 16, 256)       0
#
#  conv_pw_13 (Conv2D)         (None, 16, 16, 256)       65536
#
#  conv_pw_13_bn (BatchNormali  (None, 16, 16, 256)      1024
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 16, 16, 256)       0
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 285,364
# Trainable params: 279,892
# Non-trainable params: 5,472
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-9)
early_stop = EarlyStopping(monitor='val_loss', patience=13, restore_best_weights=True)
callbacks = [reduce_lr, early_stop]

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy', 
                       tf.keras.metrics.Precision(), 
                       tf.keras.metrics.Recall()])

# %%
epochs = 20
train_step = int(train_gen.samples/batch_size)
valid_step = int(valid_gen.samples/batch_size)

history = model.fit(
    x=train_gen,
    epochs=epochs,
    steps_per_epoch=train_step,  
    batch_size = batch_size,
    verbose=1,
    callbacks=callbacks,
    validation_data=valid_gen,
    validation_steps=valid_step,
    shuffle=False,
    initial_epoch=0
)
# Out:
# Epoch 1/20
# 53/53 [==============================] - 83s 1s/step - loss: 0.6079 - accuracy: 0.7541 - precision: 0.7844 - recall: 0.7134 - val_loss: 4.2458 - val_accuracy: 0.2594 - val_precision: 0.2594 - val_recall: 0.2594 - lr: 0.0010
# Epoch 2/20
# 53/53 [==============================] - 30s 559ms/step - loss: 0.3346 - accuracy: 0.8682 - precision: 0.8793 - recall: 0.8508 - val_loss: 3.0252 - val_accuracy: 0.4062 - val_precision: 0.4127 - val_recall: 0.4062 - lr: 0.0010
# Epoch 3/20
# 53/53 [==============================] - 29s 540ms/step - loss: 0.2654 - accuracy: 0.8971 - precision: 0.9056 - recall: 0.8886 - val_loss: 1.3391 - val_accuracy: 0.6031 - val_precision: 0.6194 - val_recall: 0.5594 - lr: 0.0010
# Epoch 4/20
# 53/53 [==============================] - 29s 548ms/step - loss: 0.2198 - accuracy: 0.9127 - precision: 0.9182 - recall: 0.9068 - val_loss: 1.0693 - val_accuracy: 0.6594 - val_precision: 0.6846 - val_recall: 0.6375 - lr: 0.0010
# Epoch 5/20
# 53/53 [==============================] - 31s 584ms/step - loss: 0.1776 - accuracy: 0.9281 - precision: 0.9340 - recall: 0.9257 - val_loss: 1.0104 - val_accuracy: 0.7531 - val_precision: 0.7628 - val_recall: 0.7437 - lr: 0.0010
# Epoch 6/20
# 53/53 [==============================] - 31s 586ms/step - loss: 0.1807 - accuracy: 0.9340 - precision: 0.9368 - recall: 0.9310 - val_loss: 0.3956 - val_accuracy: 0.8375 - val_precision: 0.8608 - val_recall: 0.8313 - lr: 0.0010
# Epoch 7/20
# 53/53 [==============================] - 30s 560ms/step - loss: 0.1503 - accuracy: 0.9428 - precision: 0.9460 - recall: 0.9402 - val_loss: 0.2530 - val_accuracy: 0.9031 - val_precision: 0.9051 - val_recall: 0.8938 - lr: 0.0010
# Epoch 8/20
# 53/53 [==============================] - 30s 554ms/step - loss: 0.1378 - accuracy: 0.9472 - precision: 0.9485 - recall: 0.9455 - val_loss: 0.2800 - val_accuracy: 0.8938 - val_precision: 0.8927 - val_recall: 0.8844 - lr: 0.0010
# Epoch 9/20
# 53/53 [==============================] - 51s 971ms/step - loss: 0.1295 - accuracy: 0.9487 - precision: 0.9500 - recall: 0.9466 - val_loss: 0.2446 - val_accuracy: 0.9094 - val_precision: 0.9119 - val_recall: 0.9062 - lr: 0.0010
# Epoch 10/20
# 53/53 [==============================] - 60s 1s/step - loss: 0.1102 - accuracy: 0.9593 - precision: 0.9601 - recall: 0.9575 - val_loss: 0.3892 - val_accuracy: 0.8656 - val_precision: 0.8734 - val_recall: 0.8625 - lr: 0.0010
# Epoch 11/20
# 53/53 [==============================] - 31s 569ms/step - loss: 0.1083 - accuracy: 0.9584 - precision: 0.9598 - recall: 0.9567 - val_loss: 0.2285 - val_accuracy: 0.9312 - val_precision: 0.9340 - val_recall: 0.9281 - lr: 0.0010
# Epoch 12/20
# 53/53 [==============================] - 30s 568ms/step - loss: 0.0896 - accuracy: 0.9652 - precision: 0.9669 - recall: 0.9640 - val_loss: 2.0823 - val_accuracy: 0.6062 - val_precision: 0.6082 - val_recall: 0.6062 - lr: 0.0010
# Epoch 13/20
# 53/53 [==============================] - 32s 602ms/step - loss: 0.0949 - accuracy: 0.9637 - precision: 0.9645 - recall: 0.9623 - val_loss: 1.1997 - val_accuracy: 0.7125 - val_precision: 0.7188 - val_recall: 0.7031 - lr: 0.0010
# Epoch 14/20
# 53/53 [==============================] - 33s 605ms/step - loss: 0.0999 - accuracy: 0.9634 - precision: 0.9640 - recall: 0.9626 - val_loss: 0.3057 - val_accuracy: 0.9062 - val_precision: 0.9091 - val_recall: 0.9062 - lr: 0.0010
# Epoch 15/20
# 53/53 [==============================] - 33s 615ms/step - loss: 0.0635 - accuracy: 0.9779 - precision: 0.9782 - recall: 0.9770 - val_loss: 0.2691 - val_accuracy: 0.9187 - val_precision: 0.9216 - val_recall: 0.9187 - lr: 2.0000e-04
# Epoch 16/20
# 53/53 [==============================] - 33s 604ms/step - loss: 0.0464 - accuracy: 0.9856 - precision: 0.9855 - recall: 0.9850 - val_loss: 0.2558 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - lr: 2.0000e-04
# Epoch 17/20
# 53/53 [==============================] - 33s 616ms/step - loss: 0.0480 - accuracy: 0.9826 - precision: 0.9829 - recall: 0.9826 - val_loss: 0.2520 - val_accuracy: 0.9312 - val_precision: 0.9312 - val_recall: 0.9312 - lr: 2.0000e-04
# Epoch 18/20
# 53/53 [==============================] - 35s 649ms/step - loss: 0.0366 - accuracy: 0.9876 - precision: 0.9876 - recall: 0.9870 - val_loss: 0.2650 - val_accuracy: 0.9344 - val_precision: 0.9342 - val_recall: 0.9312 - lr: 4.0000e-05
# Epoch 19/20
# 53/53 [==============================] - 33s 614ms/step - loss: 0.0316 - accuracy: 0.9920 - precision: 0.9923 - recall: 0.9917 - val_loss: 0.2753 - val_accuracy: 0.9312 - val_precision: 0.9312 - val_recall: 0.9312 - lr: 4.0000e-05
# Epoch 20/20
# 53/53 [==============================] - 33s 626ms/step - loss: 0.0344 - accuracy: 0.9897 - precision: 0.9897 - recall: 0.9894 - val_loss: 0.2469 - val_accuracy: 0.9344 - val_precision: 0.9344 - val_recall: 0.9344 - lr: 4.0000e-05

# %%
import seaborn as sns
import matplotlib.pyplot as plt
####################################
sns.set(style='whitegrid')
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))
sns.lineplot(x=range(1, len(history.history['accuracy']) + 1), y=history.history['accuracy'], ax=axes[0], label='train')   
sns.lineplot(x=range(1, len(history.history['val_accuracy']) + 1), y=history.history['val_accuracy'], ax=axes[0], label='test')
axes[0].set_title('Model Accuracy')
axes[0].set_ylabel('Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].legend(loc='upper left')

sns.lineplot(x=range(1, len(history.history['loss']) + 1), y=history.history['loss'], ax=axes[1], label='train')
sns.lineplot(x=range(1, len(history.history['val_loss']) + 1), y=history.history['val_loss'], ax=axes[1], label='test')
axes[1].set_title('Model Loss')
axes[1].set_ylabel('Loss')
axes[1].set_xlabel('Epoch')
axes[1].legend(loc='upper right')
plt.tight_layout()
plt.show()
####################################

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import numpy as np

####################################
steps = len(test_gen)
features = model.predict(test_gen, steps=steps, verbose=1)
features_reshaped = features.reshape((features.shape[0], -1))
tsne = TSNE(n_components=3, random_state=0)
reduced_features = tsne.fit_transform(features_reshaped)
labels = np.concatenate([test_gen[i][1] for i in range(steps)])

plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=np.argmax(labels, axis=1), cmap='viridis')
plt.colorbar()
plt.title('t-SNE Visualization of Mobilenet')
plt.show()
# Out:
# 211/211 [==============================] - 5s 23ms/step

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key            
    classes=list(new_dict.values())     
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir,dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  
        if pred_index != true_index: 
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):                
                split1=os.path.split(error_list[i])                
                split2=os.path.split(split1[0])                
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))              
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) 
                plot_class.append(value)   
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)        
    y_pred=np.array(y_pred)
    if len(classes)<= 30:
        # Create a confusion matrix
        cm = confusion_matrix(y_true, y_pred)
        length = len(classes)
        if length < 8:
            fig_width = 8
            fig_height = 8
        else:
            fig_width = int(length * 0.5)
            fig_height = int(length * 0.5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=classes, yticklabels=classes)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %%
pred = model.predict(test_gen)
print_code = 0
save_dir = "./"
subject='classes'
print_info( test_gen, pred, print_code, save_dir, subject)
# Out:
# 211/211 [==============================] - 3s 13ms/step
# Classification Report:
# ----------------------
#                        precision    recall  f1-score   support
#
#             cataract       0.96      0.99      0.98       104
# diabetic_retinopathy       1.00      1.00      1.00       110
#             glaucoma       0.95      0.81      0.88       101
#               normal       0.87      0.96      0.91       107
#
#             accuracy                           0.94       422
#            macro avg       0.95      0.94      0.94       422
#         weighted avg       0.95      0.94      0.94       422

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

pred_prob = model.predict(test_gen)

fpr = {}
tpr = {}
thresh ={}

n_class = 4

for i in range(n_class):
    fpr[i], tpr[i], thresh[i] = roc_curve(test_gen.classes, pred_prob[:,i], pos_label=i)


plt.plot(fpr[0], tpr[0], linestyle='--',color='green', label='glacoma')
plt.plot(fpr[1], tpr[1], linestyle='--',color='yellow', label='diabetic retinopathy')
plt.plot(fpr[2], tpr[2], linestyle='--',color='black', label='cataract')
plt.plot(fpr[3], tpr[3], linestyle='--',color='red', label='normal')


plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
# Out:
# 211/211 [==============================] - 3s 13ms/step
